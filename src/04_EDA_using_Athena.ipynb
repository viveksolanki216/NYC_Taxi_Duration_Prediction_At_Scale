# %% [markdown]
# # EDA Using Athena
#
# **We have resolved the column names, datatypes differences of the parquet files and created a new data catalog table**
#
# - Parquet files are usually 10% to 50% in size v/s csv files for the same dataset
# - It's not possible to load this huge data in pandas dataframe.
# - So we use Athena to explore the dataset.
#
# Docs References: https://docs.aws.amazon.com/athena/latest/ug/what-is.html

# %%
# !pip install awswrangler
# Out:
# Requirement already satisfied: awswrangler in /opt/conda/lib/python3.12/site-packages (3.12.1)
# Requirement already satisfied: boto3<2,>=1.20.32 in /opt/conda/lib/python3.12/site-packages (from awswrangler) (1.37.1)
# Requirement already satisfied: botocore<2,>=1.23.32 in /opt/conda/lib/python3.12/site-packages (from awswrangler) (1.37.1)
# Requirement already satisfied: numpy<3.0,>=1.26 in /opt/conda/lib/python3.12/site-packages (from awswrangler) (1.26.4)
# Requirement already satisfied: packaging<26.0,>=21.1 in /opt/conda/lib/python3.12/site-packages (from awswrangler) (24.2)
# Requirement already satisfied: pandas<3.0.0,>=1.2.0 in /opt/conda/lib/python3.12/site-packages (from awswrangler) (2.2.3)
# Requirement already satisfied: pyarrow<21.0.0,>=18.0.0 in /opt/conda/lib/python3.12/site-packages (from awswrangler) (19.0.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from awswrangler) (75.8.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /opt/conda/lib/python3.12/site-packages (from awswrangler) (4.12.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from boto3<2,>=1.20.32->awswrangler) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /opt/conda/lib/python3.12/site-packages (from boto3<2,>=1.20.32->awswrangler) (0.11.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.12/site-packages (from botocore<2,>=1.23.32->awswrangler) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.12/site-packages (from botocore<2,>=1.23.32->awswrangler) (2.3.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas<3.0.0,>=1.2.0->awswrangler) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas<3.0.0,>=1.2.0->awswrangler) (2025.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<2,>=1.23.32->awswrangler) (1.17.0)

# %%
import pandas as pd
import boto3
import awswrangler as wr
import sagemaker

# %%
boto_session = boto3.session.Session()
s3_client = boto_session.client('s3')
s3_output=""

# %% [markdown]
# ## Change the location of s3 data if you have moved it.

# %%
#query = """
#    ALTER TABLE raw_data
#    SET LOCATION
#"""
#df = wr.athena.start_query_execution(sql=query, database='nyc_taxi_data')
#df

# %% [markdown]
# ### Get sample of 10 rows

# %%
query = "select * from schema_corrected_data limit 100"
df = wr.athena.read_sql_query(sql=query, database='nyc_taxi_data')
wr.s3.to_csv(df=df, path=f"{s3_output}/sample_100_rows.csv", index=False)
df
# Out:
# [07/03/25 10:54:39] INFO     Created CTAS table                                                       ]8;id=955184;file:///opt/conda/lib/python3.12/site-packages/awswrangler/athena/_utils.py\_utils.py]8;;\:]8;id=292179;file:///opt/conda/lib/python3.12/site-packages/awswrangler/athena/_utils.py#872\872]8;;\
#                              "nyc_taxi_data"."temp_table_40703507253d451d822385c8fae296a4"
#     vendorid tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          1  2024-01-03 00:03:28   2024-01-03 00:22:43             <NA>
# 1          2  2019-09-25 08:53:41   2019-09-25 16:20:56                1
# 2          2  2024-01-03 00:01:18   2024-01-03 00:29:13             <NA>
# 3          1  2024-01-03 00:45:32   2024-01-03 01:26:55             <NA>
# 4          2  2024-01-03 00:29:00   2024-01-03 00:44:00             <NA>
# ..       ...                  ...                   ...              ...
# 95         2  2024-01-03 04:32:31   2024-01-03 04:58:58             <NA>
# 96         2  2024-01-03 04:47:00   2024-01-03 05:02:00             <NA>
# 97         2  2024-01-03 04:58:42   2024-01-03 05:26:33             <NA>
# 98         1  2024-01-03 04:25:21   2024-01-03 04:42:36             <NA>
# 99         1  2024-01-03 04:49:04   2024-01-03 05:05:23             <NA>
#
#     trip_distance  ratecodeid store_and_fwd_flag  pulocationid  dolocationid  \
# 0            0.00        <NA>               <NA>           193            92
# 1            2.32           1                  N           162           246
# 2            9.85        <NA>               <NA>           137            62
# 3           19.30        <NA>               <NA>           132           143
# 4            2.88        <NA>               <NA>           137            50
# ..            ...         ...                ...           ...           ...
# 95          18.39        <NA>               <NA>           181           132
# 96           8.31        <NA>               <NA>           236           138
# 97          14.17        <NA>               <NA>            89           132
# 98           0.00        <NA>               <NA>            79           138
# 99           8.10        <NA>               <NA>           141           138
#
#     payment_type  ...  extra  mta_tax  tip_amount  tolls_amount  \
# 0              0  ...   0.00      0.5        0.00          0.00
# 1              1  ...   0.00      0.5        3.96          0.00
# 2              0  ...   0.00      0.5        2.00          0.00
# 3              0  ...   1.75      0.5        4.13          6.94
# 4              0  ...   0.00      0.5        3.00          0.00
# ..           ...  ...    ...      ...         ...           ...
# 95             0  ...   0.00      0.5       11.52          0.00
# 96             0  ...   0.00      0.5        8.54          6.94
# 97             0  ...   0.00      0.5       13.72          0.00
# 98             0  ...   7.00      0.5        7.20          0.00
# 99             0  ...   0.00      0.5        0.00          6.94
#
#     improvement_surcharge  total_amount  congestion_surcharge  airport_fee  \
# 0                     1.0         28.46                   NaN          NaN
# 1                     0.3         23.76                   2.5          NaN
# 2                     1.0         42.44                   NaN          NaN
# 3                     1.0         86.82                   NaN          NaN
# 4                     1.0         23.67                   NaN          NaN
# ..                    ...           ...                   ...          ...
# 95                    1.0         69.11                   NaN          NaN
# 96                    1.0         51.26                   NaN          NaN
# 97                    1.0         68.59                   NaN          NaN
# 98                    1.0         57.20                   NaN          NaN
# 99                    1.0         43.44                   NaN          NaN
#
#     cbd_congestion_fee  tpep_pickup_date
# 0                  NaN        2024-01-03
# 1                  NaN        2019-09-25
# 2                  NaN        2024-01-03
# 3                  NaN        2024-01-03
# 4                  NaN        2024-01-03
# ..                 ...               ...
# 95                 NaN        2024-01-03
# 96                 NaN        2024-01-03
# 97                 NaN        2024-01-03
# 98                 NaN        2024-01-03
# 99                 NaN        2024-01-03
#
# [100 rows x 21 columns]

# %%
query = """
    SELECT 
    column_name, data_type 
    FROM information_schema.columns 
    WHERE table_schema = 'nyc_taxi_data' 
    AND table_name = 'schema_corrected_data';
    """ 

table_schema = wr.athena.read_sql_query(sql=query, database='nyc_taxi_data')
columns = table_schema['column_name'].tolist()
datatypes = table_schema['data_type'].tolist()
table_schema
# Out:
# [07/03/25 11:12:38] INFO     Created CTAS table                                                       ]8;id=109688;file:///opt/conda/lib/python3.12/site-packages/awswrangler/athena/_utils.py\_utils.py]8;;\:]8;id=841870;file:///opt/conda/lib/python3.12/site-packages/awswrangler/athena/_utils.py#872\872]8;;\
#                              "nyc_taxi_data"."temp_table_60cf73420fae41219335ee529b5a8b2a"
#               column_name     data_type
# 0                vendorid       integer
# 1    tpep_pickup_datetime  timestamp(3)
# 2   tpep_dropoff_datetime  timestamp(3)
# 3         passenger_count       integer
# 4           trip_distance        double
# 5              ratecodeid       integer
# 6      store_and_fwd_flag       varchar
# 7            pulocationid       integer
# 8            dolocationid       integer
# 9            payment_type       integer
# 10            fare_amount        double
# 11                  extra        double
# 12                mta_tax        double
# 13             tip_amount        double
# 14           tolls_amount        double
# 15  improvement_surcharge        double
# 16           total_amount        double
# 17   congestion_surcharge        double
# 18            airport_fee        double
# 19     cbd_congestion_fee        double
# 20       tpep_pickup_date       varchar

# %% [markdown]
# ### Get By Year Summary

# %%
query = """
    SELECT 
        year(tpep_pickup_datetime) AS year, 
        COUNT(*) as total_trips, 
        ROUND(SUM(total_amount) / 1000000, 0) as total_amount,
        ROUND(SUM(fare_amount) / 1000000, 0) as fare_amount, 
        ROUND(SUM(tip_amount) / 1000000, 0) as tip_amount
    FROM schema_corrected_data 
    GROUP BY year(tpep_pickup_datetime)
    ORDER BY 1
"""
df = wr.athena.read_sql_query(sql=query, database='nyc_taxi_data')
wr.s3.to_csv(df=df, path=f"{s3_output}/summary_by_year.csv", index=False)
df
# Out:
# [07/03/25 10:42:12] INFO     Created CTAS table                                                       ]8;id=735724;file:///opt/conda/lib/python3.12/site-packages/awswrangler/athena/_utils.py\_utils.py]8;;\:]8;id=601173;file:///opt/conda/lib/python3.12/site-packages/awswrangler/athena/_utils.py#872\872]8;;\
#                              "nyc_taxi_data"."temp_table_2f5751eae3214ab284a763c96c3b8080"
#     year  total_trips  total_amount  fare_amount  tip_amount
# 0   2001           15           0.0          0.0         0.0
# 1   2002          478           0.0          0.0         0.0
# 2   2003           33           0.0          0.0         0.0
# 3   2004            1           0.0          0.0         0.0
# 4   2007            1           0.0          0.0         0.0
# 5   2008          366           0.0          0.0         0.0
# 6   2009          744           0.0          0.0         0.0
# 7   2010            1           0.0          0.0         0.0
# 8   2011            4           0.0          0.0         0.0
# 9   2012            1           0.0          0.0         0.0
# 10  2014            1           0.0          0.0         0.0
# 11  2015            1           0.0          0.0         0.0
# 12  2018          366           0.0          0.0         0.0
# 13  2019     77383319        1481.0       1036.0       169.0
# 14  2020     24649226         454.0        312.0        51.0
# 15  2021     30903982         609.0        418.0        72.0
# 16  2022     39655622         859.0        411.0       287.0
# 17  2023     38310138        1090.0        748.0       135.0
# 18  2024     41169691        1146.0        793.0       136.0
# 19  2025     19760405         516.0        349.0        57.0
# 20  2026            3           0.0          0.0         0.0
# 21  2028            1           0.0          0.0         0.0
# 22  2029            5           0.0          0.0         0.0
# 23  2033            3           0.0          0.0         0.0
# 24  2038            4           0.0          0.0         0.0
# 25  2041            1           0.0          0.0         0.0
# 26  2058            3           0.0          0.0         0.0
# 27  2066            1           0.0          0.0         0.0
# 28  2070            1           0.0          0.0         0.0
# 29  2088            2           0.0          0.0         0.0
# 30  2090            1           0.0          0.0         0.0
# 31  2098            1           0.0          0.0         0.0

# %% [markdown]
# ### Missingness in the data

# %%
#        date_format(tpep_pickup_datetime, "%Y%m) as month_year,
query = f"""
    SELECT 
        year(tpep_pickup_datetime) as year,
        month(tpep_pickup_datetime) as month,
        COUNT(*) as total_rows,
        {' , '.join([
            'ROUND(100 - (100 * COUNT({}) / COUNT(*)), 1) AS {}'.format(col, col) 
            for col in columns
        ])}
    FROM schema_corrected_data
    GROUP BY month(tpep_pickup_datetime), year(tpep_pickup_datetime) 
    ORDER BY year, month
"""
print(query)
df = wr.athena.read_sql_query(sql=query, database='nyc_taxi_data', s3_output="s3://sagemaker-us-east-1-205930620783/NYC_Taxi_Prediction/")
wr.s3.to_csv(df=df, path=f"{s3_output}/missingness_by_month_year.csv", index=False)#df.to_csv("")
# Out:
#     SELECT
#         year(tpep_pickup_datetime) as year,
#         month(tpep_pickup_datetime) as month,
#         COUNT(*) as total_rows,
#         ROUND(100 - (100 * COUNT(vendorid) / COUNT(*)), 1) AS vendorid , ROUND(100 - (100 * COUNT(tpep_pickup_datetime) / COUNT(*)), 1) AS tpep_pickup_datetime , ROUND(100 - (100 * COUNT(tpep_dropoff_datetime) / COUNT(*)), 1) AS tpep_dropoff_datetime , ROUND(100 - (100 * COUNT(passenger_count) / COUNT(*)), 1) AS passenger_count , ROUND(100 - (100 * COUNT(trip_distance) / COUNT(*)), 1) AS trip_distance , ROUND(100 - (100 * COUNT(ratecodeid) / COUNT(*)), 1) AS ratecodeid , ROUND(100 - (100 * COUNT(store_and_fwd_flag) / COUNT(*)), 1) AS store_and_fwd_flag , ROUND(100 - (100 * COUNT(pulocationid) / COUNT(*)), 1) AS pulocationid , ROUND(100 - (100 * COUNT(dolocationid) / COUNT(*)), 1) AS dolocationid , ROUND(100 - (100 * COUNT(payment_type) / COUNT(*)), 1) AS payment_type , ROUND(100 - (100 * COUNT(fare_amount) / COUNT(*)), 1) AS fare_amount , ROUND(100 - (100 * COUNT(extra) / COUNT(*)), 1) AS extra , ROUND(100 - (100 * COUNT(mta_tax) / COUNT(*)), 1) AS mta_tax , ROUND(100 - (100 * COUNT(tip_amount) / COUNT(*)), 1) AS tip_amount , ROUND(100 - (100 * COUNT(tolls_amount) / COUNT(*)), 1) AS tolls_amount , ROUND(100 - (100 * COUNT(improvement_surcharge) / COUNT(*)), 1) AS improvement_surcharge , ROUND(100 - (100 * COUNT(total_amount) / COUNT(*)), 1) AS total_amount , ROUND(100 - (100 * COUNT(congestion_surcharge) / COUNT(*)), 1) AS congestion_surcharge , ROUND(100 - (100 * COUNT(airport_fee) / COUNT(*)), 1) AS airport_fee , ROUND(100 - (100 * COUNT(cbd_congestion_fee) / COUNT(*)), 1) AS cbd_congestion_fee
#     FROM schema_corrected_data
#     GROUP BY month(tpep_pickup_datetime), year(tpep_pickup_datetime)
#     ORDER BY year, month
# [07/03/25 10:58:44] INFO     Created CTAS table                                                       ]8;id=569330;file:///opt/conda/lib/python3.12/site-packages/awswrangler/athena/_utils.py\_utils.py]8;;\:]8;id=157501;file:///opt/conda/lib/python3.12/site-packages/awswrangler/athena/_utils.py#872\872]8;;\
#                              "nyc_taxi_data"."temp_table_225cd5298264459a8ce1754cfdc608a9"
# {'paths': ['s3://sagemaker-us-east-1-205930620783/NYC_Taxi_Prediction/athena_query_results/missingness_by_month_year.csv'],
#  'partitions_values': {}}

# %% [markdown]
# ## Distribution of each columns

# %%
numeric_types = ['integer', 'bigint', 'double', 'float', 'decimal']
categorical_types = ['varchar', 'string', 'char', 'boolean']

numeric_f, categorical_f = [], []
for col_name, data_type in zip(columns, datatypes):
    print(col_name)
    if data_type in numeric_types:
        numeric_f.append(col_name)
    elif data_type in categorical_types:
        categorical_f.append(col_name)
    else:
        print("pass")

print("Numerical Columns: ", numeric_f)
print("Categorical Columns: ", categorical_f)
# Out:
# vendorid
# tpep_pickup_datetime
# pass
# tpep_dropoff_datetime
# pass
# passenger_count
# trip_distance
# ratecodeid
# store_and_fwd_flag
# pulocationid
# dolocationid
# payment_type
# fare_amount
# extra
# mta_tax
# tip_amount
# tolls_amount
# improvement_surcharge
# total_amount
# congestion_surcharge
# airport_fee
# cbd_congestion_fee
# tpep_pickup_date
# Numerical Columns:  ['vendorid', 'passenger_count', 'trip_distance', 'ratecodeid', 'pulocationid', 'dolocationid', 'payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount', 'congestion_surcharge', 'airport_fee', 'cbd_congestion_fee']
# Categorical Columns:  ['store_and_fwd_flag', 'tpep_pickup_date']

# %% [markdown]
# ### Distribution of Numerical Fields

# %%
summary_expr = []
for col in numeric_f:
    summary_expr.extend([
        f"ROUND(MIN({col}),3) AS {col}_min",
        f"ROUND(MAX({col}),3) AS {col}_max",
        f"ROUND(AVG({col}),3) AS {col}_mean",
        f"ROUND(STDDEV({col}),3) AS {col}_std",
        f"ROUND(approx_percentile({col}, 0.25),3) AS {col}_p25",
        f"ROUND(approx_percentile({col}, 0.5),3) AS {col}_p50",
        f"ROUND(approx_percentile({col}, 0.75),3) AS {col}_p75"
    ])

query = f"""
    SELECT
        year(tpep_pickup_datetime) as year,
        {',\n '.join(summary_expr)}
    FROM schema_corrected_data
    GROUP BY year(tpep_pickup_datetime)
    ORDER BY year
"""
print(query)
df = wr.athena.read_sql_query(sql=query, database='nyc_taxi_data', s3_output="s3://sagemaker-us-east-1-205930620783/NYC_Taxi_Prediction/")
wr.s3.to_csv(df=df, path=f"{s3_output}/numeric_features_summary.csv", index=False)#df.to_csv("")

df.head(10)
# Out:
#     SELECT
#         year(tpep_pickup_datetime) as year,
#         ROUND(MIN(vendorid),3) AS vendorid_min,
#  ROUND(MAX(vendorid),3) AS vendorid_max,
#  ROUND(AVG(vendorid),3) AS vendorid_mean,
#  ROUND(STDDEV(vendorid),3) AS vendorid_std,
#  ROUND(approx_percentile(vendorid, 0.25),3) AS vendorid_p25,
#  ROUND(approx_percentile(vendorid, 0.5),3) AS vendorid_p50,
#  ROUND(approx_percentile(vendorid, 0.75),3) AS vendorid_p75,
#  ROUND(MIN(passenger_count),3) AS passenger_count_min,
#  ROUND(MAX(passenger_count),3) AS passenger_count_max,
#  ROUND(AVG(passenger_count),3) AS passenger_count_mean,
#  ROUND(STDDEV(passenger_count),3) AS passenger_count_std,
#  ROUND(approx_percentile(passenger_count, 0.25),3) AS passenger_count_p25,
#  ROUND(approx_percentile(passenger_count, 0.5),3) AS passenger_count_p50,
#  ROUND(approx_percentile(passenger_count, 0.75),3) AS passenger_count_p75,
#  ROUND(MIN(trip_distance),3) AS trip_distance_min,
#  ROUND(MAX(trip_distance),3) AS trip_distance_max,
#  ROUND(AVG(trip_distance),3) AS trip_distance_mean,
#  ROUND(STDDEV(trip_distance),3) AS trip_distance_std,
#  ROUND(approx_percentile(trip_distance, 0.25),3) AS trip_distance_p25,
#  ROUND(approx_percentile(trip_distance, 0.5),3) AS trip_distance_p50,
#  ROUND(approx_percentile(trip_distance, 0.75),3) AS trip_distance_p75,
#  ROUND(MIN(ratecodeid),3) AS ratecodeid_min,
#  ROUND(MAX(ratecodeid),3) AS ratecodeid_max,
#  ROUND(AVG(ratecodeid),3) AS ratecodeid_mean,
#  ROUND(STDDEV(ratecodeid),3) AS ratecodeid_std,
#  ROUND(approx_percentile(ratecodeid, 0.25),3) AS ratecodeid_p25,
#  ROUND(approx_percentile(ratecodeid, 0.5),3) AS ratecodeid_p50,
#  ROUND(approx_percentile(ratecodeid, 0.75),3) AS ratecodeid_p75,
#  ROUND(MIN(pulocationid),3) AS pulocationid_min,
#  ROUND(MAX(pulocationid),3) AS pulocationid_max,
#  ROUND(AVG(pulocationid),3) AS pulocationid_mean,
#  ROUND(STDDEV(pulocationid),3) AS pulocationid_std,
#  ROUND(approx_percentile(pulocationid, 0.25),3) AS pulocationid_p25,
#  ROUND(approx_percentile(pulocationid, 0.5),3) AS pulocationid_p50,
#  ROUND(approx_percentile(pulocationid, 0.75),3) AS pulocationid_p75,
#  ROUND(MIN(dolocationid),3) AS dolocationid_min,
#  ROUND(MAX(dolocationid),3) AS dolocationid_max,
#  ROUND(AVG(dolocationid),3) AS dolocationid_mean,
#  ROUND(STDDEV(dolocationid),3) AS dolocationid_std,
#  ROUND(approx_percentile(dolocationid, 0.25),3) AS dolocationid_p25,
#  ROUND(approx_percentile(dolocationid, 0.5),3) AS dolocationid_p50,
#  ROUND(approx_percentile(dolocationid, 0.75),3) AS dolocationid_p75,
#  ROUND(MIN(payment_type),3) AS payment_type_min,
#  ROUND(MAX(payment_type),3) AS payment_type_max,
#  ROUND(AVG(payment_type),3) AS payment_type_mean,
#  ROUND(STDDEV(payment_type),3) AS payment_type_std,
#  ROUND(approx_percentile(payment_type, 0.25),3) AS payment_type_p25,
#  ROUND(approx_percentile(payment_type, 0.5),3) AS payment_type_p50,
#  ROUND(approx_percentile(payment_type, 0.75),3) AS payment_type_p75,
#  ROUND(MIN(fare_amount),3) AS fare_amount_min,
#  ROUND(MAX(fare_amount),3) AS fare_amount_max,
#  ROUND(AVG(fare_amount),3) AS fare_amount_mean,
#  ROUND(STDDEV(fare_amount),3) AS fare_amount_std,
#  ROUND(approx_percentile(fare_amount, 0.25),3) AS fare_amount_p25,
#  ROUND(approx_percentile(fare_amount, 0.5),3) AS fare_amount_p50,
#  ROUND(approx_percentile(fare_amount, 0.75),3) AS fare_amount_p75,
#  ROUND(MIN(extra),3) AS extra_min,
#  ROUND(MAX(extra),3) AS extra_max,
#  ROUND(AVG(extra),3) AS extra_mean,
#  ROUND(STDDEV(extra),3) AS extra_std,
#  ROUND(approx_percentile(extra, 0.25),3) AS extra_p25,
#  ROUND(approx_percentile(extra, 0.5),3) AS extra_p50,
#  ROUND(approx_percentile(extra, 0.75),3) AS extra_p75,
#  ROUND(MIN(mta_tax),3) AS mta_tax_min,
#  ROUND(MAX(mta_tax),3) AS mta_tax_max,
#  ROUND(AVG(mta_tax),3) AS mta_tax_mean,
#  ROUND(STDDEV(mta_tax),3) AS mta_tax_std,
#  ROUND(approx_percentile(mta_tax, 0.25),3) AS mta_tax_p25,
#  ROUND(approx_percentile(mta_tax, 0.5),3) AS mta_tax_p50,
#  ROUND(approx_percentile(mta_tax, 0.75),3) AS mta_tax_p75,
#  ROUND(MIN(tip_amount),3) AS tip_amount_min,
#  ROUND(MAX(tip_amount),3) AS tip_amount_max,
#  ROUND(AVG(tip_amount),3) AS tip_amount_mean,
#  ROUND(STDDEV(tip_amount),3) AS tip_amount_std,
#  ROUND(approx_percentile(tip_amount, 0.25),3) AS tip_amount_p25,
#  ROUND(approx_percentile(tip_amount, 0.5),3) AS tip_amount_p50,
#  ROUND(approx_percentile(tip_amount, 0.75),3) AS tip_amount_p75,
#  ROUND(MIN(tolls_amount),3) AS tolls_amount_min,
#  ROUND(MAX(tolls_amount),3) AS tolls_amount_max,
#  ROUND(AVG(tolls_amount),3) AS tolls_amount_mean,
#  ROUND(STDDEV(tolls_amount),3) AS tolls_amount_std,
#  ROUND(approx_percentile(tolls_amount, 0.25),3) AS tolls_amount_p25,
#  ROUND(approx_percentile(tolls_amount, 0.5),3) AS tolls_amount_p50,
#  ROUND(approx_percentile(tolls_amount, 0.75),3) AS tolls_amount_p75,
#  ROUND(MIN(improvement_surcharge),3) AS improvement_surcharge_min,
#  ROUND(MAX(improvement_surcharge),3) AS improvement_surcharge_max,
#  ROUND(AVG(improvement_surcharge),3) AS improvement_surcharge_mean,
#  ROUND(STDDEV(improvement_surcharge),3) AS improvement_surcharge_std,
#  ROUND(approx_percentile(improvement_surcharge, 0.25),3) AS improvement_surcharge_p25,
#  ROUND(approx_percentile(improvement_surcharge, 0.5),3) AS improvement_surcharge_p50,
#  ROUND(approx_percentile(improvement_surcharge, 0.75),3) AS improvement_surcharge_p75,
#  ROUND(MIN(total_amount),3) AS total_amount_min,
#  ROUND(MAX(total_amount),3) AS total_amount_max,
#  ROUND(AVG(total_amount),3) AS total_amount_mean,
#  ROUND(STDDEV(total_amount),3) AS total_amount_std,
#  ROUND(approx_percentile(total_amount, 0.25),3) AS total_amount_p25,
#  ROUND(approx_percentile(total_amount, 0.5),3) AS total_amount_p50,
#  ROUND(approx_percentile(total_amount, 0.75),3) AS total_amount_p75,
#  ROUND(MIN(congestion_surcharge),3) AS congestion_surcharge_min,
#  ROUND(MAX(congestion_surcharge),3) AS congestion_surcharge_max,
#  ROUND(AVG(congestion_surcharge),3) AS congestion_surcharge_mean,
#  ROUND(STDDEV(congestion_surcharge),3) AS congestion_surcharge_std,
#  ROUND(approx_percentile(congestion_surcharge, 0.25),3) AS congestion_surcharge_p25,
#  ROUND(approx_percentile(congestion_surcharge, 0.5),3) AS congestion_surcharge_p50,
#  ROUND(approx_percentile(congestion_surcharge, 0.75),3) AS congestion_surcharge_p75,
#  ROUND(MIN(airport_fee),3) AS airport_fee_min,
#  ROUND(MAX(airport_fee),3) AS airport_fee_max,
#  ROUND(AVG(airport_fee),3) AS airport_fee_mean,
#  ROUND(STDDEV(airport_fee),3) AS airport_fee_std,
#  ROUND(approx_percentile(airport_fee, 0.25),3) AS airport_fee_p25,
#  ROUND(approx_percentile(airport_fee, 0.5),3) AS airport_fee_p50,
#  ROUND(approx_percentile(airport_fee, 0.75),3) AS airport_fee_p75,
#  ROUND(MIN(cbd_congestion_fee),3) AS cbd_congestion_fee_min,
#  ROUND(MAX(cbd_congestion_fee),3) AS cbd_congestion_fee_max,
#  ROUND(AVG(cbd_congestion_fee),3) AS cbd_congestion_fee_mean,
#  ROUND(STDDEV(cbd_congestion_fee),3) AS cbd_congestion_fee_std,
#  ROUND(approx_percentile(cbd_congestion_fee, 0.25),3) AS cbd_congestion_fee_p25,
#  ROUND(approx_percentile(cbd_congestion_fee, 0.5),3) AS cbd_congestion_fee_p50,
#  ROUND(approx_percentile(cbd_congestion_fee, 0.75),3) AS cbd_congestion_fee_p75
#     FROM schema_corrected_data
#     GROUP BY year(tpep_pickup_datetime)
#     ORDER BY year
# [07/03/25 11:37:31] INFO     Created CTAS table                                                       ]8;id=303524;file:///opt/conda/lib/python3.12/site-packages/awswrangler/athena/_utils.py\_utils.py]8;;\:]8;id=722334;file:///opt/conda/lib/python3.12/site-packages/awswrangler/athena/_utils.py#872\872]8;;\
#                              "nyc_taxi_data"."temp_table_4bec43adeccd42eb923a4561a29c77d5"
#    year  vendorid_min  vendorid_max  vendorid_mean  vendorid_std  \
# 0  2001             2             2            2.0           0.0
# 1  2002             2             2            2.0           0.0
# 2  2003             2             2            2.0           0.0
# 3  2004             2             2            2.0           NaN
# 4  2007             2             2            2.0           NaN
# 5  2008             2             2            2.0           0.0
# 6  2009             2             2            2.0           0.0
# 7  2010             2             2            2.0           NaN
# 8  2011             2             2            2.0           0.0
# 9  2012             2             2            2.0           NaN
#
#    vendorid_p25  vendorid_p50  vendorid_p75  passenger_count_min  \
# 0             2             2             2                    1
# 1             2             2             2                    1
# 2             2             2             2                    1
# 3             2             2             2                    1
# 4             2             2             2                    1
# 5             2             2             2                    1
# 6             2             2             2                    1
# 7             2             2             2                    2
# 8             2             2             2                    1
# 9             2             2             2                    1
#
#    passenger_count_max  ...  airport_fee_p25  airport_fee_p50  \
# 0                    2  ...              0.0              0.0
# 1                    4  ...              0.0              0.0
# 2                    6  ...              0.0              0.0
# 3                    1  ...              0.0              0.0
# 4                    1  ...              0.0              0.0
# 5                    6  ...              0.0              0.0
# 6                    6  ...              0.0              0.0
# 7                    2  ...              NaN              NaN
# 8                    1  ...              0.0              0.0
# 9                    1  ...              0.0              0.0
#
#    airport_fee_p75  cbd_congestion_fee_min  cbd_congestion_fee_max  \
# 0            1.250                     NaN                     NaN
# 1            0.000                     NaN                     NaN
# 2            0.000                     NaN                     NaN
# 3            0.000                     NaN                     NaN
# 4            0.000                    0.75                    0.75
# 5            0.313                     NaN                     NaN
# 6            0.000                    0.00                    0.75
# 7              NaN                     NaN                     NaN
# 8            0.000                     NaN                     NaN
# 9            0.000                     NaN                     NaN
#
#    cbd_congestion_fee_mean  cbd_congestion_fee_std  cbd_congestion_fee_p25  \
# 0                      NaN                     NaN                     NaN
# 1                      NaN                     NaN                     NaN
# 2                      NaN                     NaN                     NaN
# 3                      NaN                     NaN                     NaN
# 4                    0.750                     NaN                    0.75
# 5                      NaN                     NaN                     NaN
# 6                    0.375                    0.53                    0.00
# 7                      NaN                     NaN                     NaN
# 8                      NaN                     NaN                     NaN
# 9                      NaN                     NaN                     NaN
#
#    cbd_congestion_fee_p50  cbd_congestion_fee_p75
# 0                     NaN                     NaN
# 1                     NaN                     NaN
# 2                     NaN                     NaN
# 3                     NaN                     NaN
# 4                    0.75                    0.75
# 5                     NaN                     NaN
# 6                    0.75                    0.75
# 7                     NaN                     NaN
# 8                     NaN                     NaN
# 9                     NaN                     NaN
#
# [10 rows x 120 columns]

# %%
for col in categorical_f:
    top_cat_sql = f"""
        SELECT {col}, COUNT(*) AS count 
        FROM schema_corrected_data
        GROUP BY {col}
        ORDER BY count DESC
        LIMIT 5
    """
    df = wr.athena.read_sql_query(top_cat_sql, database='nyc_taxi_data')
    display(df)
# Out:
# [07/03/25 11:39:26] INFO     Created CTAS table                                                       ]8;id=198698;file:///opt/conda/lib/python3.12/site-packages/awswrangler/athena/_utils.py\_utils.py]8;;\:]8;id=914422;file:///opt/conda/lib/python3.12/site-packages/awswrangler/athena/_utils.py#872\872]8;;\
#                              "nyc_taxi_data"."temp_table_05dcfb71b4524e2cbd545711ba617bf2"
#   store_and_fwd_flag      count
# 0                  N  255934077
# 1               <NA>   13660868
# 2                  Y    2239476
# [07/03/25 11:39:36] INFO     Created CTAS table                                                       ]8;id=330361;file:///opt/conda/lib/python3.12/site-packages/awswrangler/athena/_utils.py\_utils.py]8;;\:]8;id=69807;file:///opt/conda/lib/python3.12/site-packages/awswrangler/athena/_utils.py#872\872]8;;\
#                              "nyc_taxi_data"."temp_table_be166a097ae04d358e06745fa2d65849"
#   tpep_pickup_date   count
# 0       2019-02-01  299261
# 1       2019-04-05  293969
# 2       2019-01-25  292499
# 3       2019-03-07  292405
# 4       2019-01-11  291714
